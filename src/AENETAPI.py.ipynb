# %%
import requests
import json
import pandas as pd

# %%
fechaIniStr='2016-01-01T00%3A00%3A00UTC'
fechaFinStr= '2016-15-01T00:00:00UTC'
idema= '8416'

def aenet_call(fechaIniStr, fechaFinStr, idema):
    '''calls AENET API'''
    api_key= "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJkZWxhZnVlbnRlLmVsZW5hQGdtYWlsLmNvbSIsImp0aSI6IjU2ZjY1YWExLTBhMDMtNDU0Ny04MTY4LWFmZjdlN2NmNGFkYiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNTc2MDA5MjE2LCJ1c2VySWQiOiI1NmY2NWFhMS0wYTAzLTQ1NDctODE2OC1hZmY3ZTdjZjRhZGIiLCJyb2xlIjoiIn0.mXzVnU06yA2hXAR4fJkyOmTXC7RfAYxTVPESkNBhvaM"
    headers = {'cache-control': "no-cache"}
    url = f'https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fechaIniStr}/fechafin/{fechaFinStr}/estacion/{idema}'
    response = requests.request('GET', url, headers=headers, params= {"api_key":api_key} )
    return json.loads(response.text)

# %%
respuesta=aenet_call('2016-01-01T00%3A00%3A00UTC', '2016-15-01T00:00:00UTC','8416')
respuesta
# Out:
# {'descripcion': 'exito',
#  'estado': 200,
#  'datos': 'https://opendata.aemet.es/opendata/sh/281f3254',
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}

# %%
print(type(respuesta))
respuesta['datos']
# Out:
# <class 'dict'>
# 'https://opendata.aemet.es/opendata/sh/281f3254'

# %%
def getdatos(url):
    '''downloads data from URL'''
    response = requests.get(url)
    return json.loads(response.text)

# %%
info=getdatos(respuesta['datos'])
info
# Out:
# [{'fecha': '2016-01-01',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,4',
#   'prec': '0,0',
#   'tmin': '12,7',
#   'tmax': '18,0',
#   'sol': '1,8'},
#  {'fecha': '2016-01-02',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,9',
#   'prec': '0,0',
#   'tmin': '12,8',
#   'tmax': '19,0',
#   'sol': '5,6'},
#  {'fecha': '2016-01-03',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,2',
#   'prec': '0,0',
#   'tmin': '10,0',
#   'tmax': '20,4',
#   'sol': '0,0'},
#  {'fecha': '2016-01-04',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '20,8',
#   'prec': '0,0',
#   'tmin': '18,1',
#   'tmax': '23,5',
#   'sol': '1,7'},
#  {'fecha': '2016-01-05',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,5',
#   'prec': '0,0',
#   'tmin': '13,2',
#   'tmax': '17,8',
#   'sol': '6,2'},
#  {'fecha': '2016-01-06',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,0',
#   'prec': '0,0',
#   'tmin': '8,7',
#   'tmax': '15,2',
#   'sol': '4,1'},
#  {'fecha': '2016-01-07',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,3',
#   'prec': '0,0',
#   'tmin': '14,0',
#   'tmax': '20,6',
#   'sol': '1,2'},
#  {'fecha': '2016-01-08',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,0',
#   'prec': '0,0',
#   'tmin': '16,0',
#   'tmax': '22,1',
#   'sol': '7,5'},
#  {'fecha': '2016-01-09',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,0',
#   'prec': '0,0',
#   'tmin': '15,5',
#   'tmax': '22,6',
#   'sol': '4,0'},
#  {'fecha': '2016-01-10',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,7',
#   'prec': '0,0',
#   'tmin': '15,0',
#   'tmax': '20,4',
#   'sol': '1,5'},
#  {'fecha': '2016-01-11',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,0',
#   'prec': '0,0',
#   'tmin': '13,0',
#   'tmax': '19,1',
#   'sol': '1,9'},
#  {'fecha': '2016-01-12',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,9',
#   'prec': '0,0',
#   'tmin': '10,0',
#   'tmax': '17,8',
#   'sol': '8,6'},
#  {'fecha': '2016-01-13',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,3',
#   'prec': '0,0',
#   'tmin': '7,5',
#   'tmax': '17,1',
#   'sol': '7,1'},
#  {'fecha': '2016-01-14',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,6',
#   'prec': '0,0',
#   'tmin': '7,5',
#   'tmax': '19,6',
#   'sol': '0,8'},
#  {'fecha': '2016-01-15',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,7',
#   'prec': '0,6',
#   'tmin': '11,6',
#   'tmax': '17,8',
#   'sol': '4,0'},
#  {'fecha': '2016-01-16',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,0',
#   'prec': '0,5',
#   'tmin': '7,0',
#   'tmax': '14,9',
#   'sol': '8,9'},
#  {'fecha': '2016-01-17',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '9,0',
#   'prec': '0,0',
#   'tmin': '2,8',
#   'tmax': '15,3',
#   'sol': '3,3'},
#  {'fecha': '2016-01-18',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,3',
#   'prec': '0,0',
#   'tmin': '5,6',
#   'tmax': '19,0',
#   'sol': '8,1'},
#  {'fecha': '2016-01-19',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,9',
#   'prec': '0,0',
#   'tmin': '6,3',
#   'tmax': '17,5',
#   'sol': '6,6'},
#  {'fecha': '2016-01-20',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,6',
#   'prec': '0,0',
#   'tmin': '8,1',
#   'tmax': '17,0',
#   'sol': '8,1'},
#  {'fecha': '2016-01-21',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,1',
#   'prec': '0,0',
#   'tmin': '7,0',
#   'tmax': '17,2',
#   'sol': '8,2'},
#  {'fecha': '2016-01-22',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,4',
#   'prec': '0,0',
#   'tmin': '7,1',
#   'tmax': '17,6',
#   'sol': '5,0'},
#  {'fecha': '2016-01-23',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,6',
#   'prec': '0,0',
#   'tmin': '8,8',
#   'tmax': '18,4',
#   'sol': '5,5'},
#  {'fecha': '2016-01-24',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,0',
#   'prec': '0,0',
#   'tmin': '8,2',
#   'tmax': '15,8',
#   'sol': '0,4'},
#  {'fecha': '2016-01-25',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,6',
#   'prec': '0,0',
#   'tmin': '13,5',
#   'tmax': '17,6',
#   'sol': '5,6'},
#  {'fecha': '2016-01-26',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,4',
#   'prec': '0,0',
#   'tmin': '12,4',
#   'tmax': '16,5',
#   'sol': '0,0'},
#  {'fecha': '2016-01-27',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,4',
#   'prec': '0,0',
#   'tmin': '12,7',
#   'tmax': '18,2',
#   'sol': '7,1'},
#  {'fecha': '2016-01-28',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,9',
#   'prec': '0,0',
#   'tmin': '9,3',
#   'tmax': '20,5',
#   'sol': '7,4'},
#  {'fecha': '2016-01-29',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,0',
#   'prec': '0,1',
#   'tmin': '11,6',
#   'tmax': '14,5',
#   'sol': '0,0'},
#  {'fecha': '2016-01-30',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,6',
#   'prec': '0,0',
#   'tmin': '8,4',
#   'tmax': '20,7',
#   'sol': '8,5'},
#  {'fecha': '2016-01-31',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,2',
#   'prec': '0,0',
#   'tmin': '11,5',
#   'tmax': '22,8',
#   'sol': '3,4'},
#  {'fecha': '2016-02-01',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,0',
#   'prec': '0,0',
#   'tmin': '10,4',
#   'tmax': '21,5',
#   'sol': '9,2'},
#  {'fecha': '2016-02-02',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,0',
#   'prec': '0,0',
#   'tmin': '9,0',
#   'tmax': '19,0',
#   'sol': '7,9'},
#  {'fecha': '2016-02-03',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,2',
#   'prec': '0,0',
#   'tmin': '8,4',
#   'tmax': '22,0',
#   'sol': '6,1'},
#  {'fecha': '2016-02-04',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,4',
#   'prec': '0,0',
#   'tmin': '6,6',
#   'tmax': '16,1',
#   'sol': '7,9'},
#  {'fecha': '2016-02-05',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,2',
#   'prec': '0,0',
#   'tmin': '6,1',
#   'tmax': '16,4',
#   'sol': '7,0'},
#  {'fecha': '2016-02-06',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,0',
#   'prec': '1,3',
#   'tmin': '6,6',
#   'tmax': '17,3',
#   'sol': '2,2'},
#  {'fecha': '2016-02-07',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,2',
#   'prec': '0,0',
#   'tmin': '10,5',
#   'tmax': '17,9',
#   'sol': '8,0'},
#  {'fecha': '2016-02-08',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,6',
#   'prec': '0,0',
#   'tmin': '12,0',
#   'tmax': '21,3',
#   'sol': '8,4'},
#  {'fecha': '2016-02-09',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,3',
#   'prec': '0,0',
#   'tmin': '14,6',
#   'tmax': '20,0',
#   'sol': '0,6'},
#  {'fecha': '2016-02-10',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '18,4',
#   'prec': '0,0',
#   'tmin': '16,5',
#   'tmax': '20,4',
#   'sol': '4,5'},
#  {'fecha': '2016-02-11',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,4',
#   'prec': '0,0',
#   'tmin': '17,4',
#   'tmax': '21,5',
#   'sol': '4,0'},
#  {'fecha': '2016-02-12',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '18,4',
#   'prec': '0,0',
#   'tmin': '16,0',
#   'tmax': '20,9',
#   'sol': '0,2'},
#  {'fecha': '2016-02-13',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '21,2',
#   'prec': '0,0',
#   'tmin': '19,0',
#   'tmax': '23,5',
#   'sol': '2,0'},
#  {'fecha': '2016-02-14',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,4',
#   'prec': '0,6',
#   'tmin': '15,5',
#   'tmax': '19,3',
#   'sol': '5,4'},
#  {'fecha': '2016-02-15',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,5',
#   'prec': '0,0',
#   'tmin': '8,4',
#   'tmax': '18,6',
#   'sol': '7,1'},
#  {'fecha': '2016-02-16',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '10,2',
#   'prec': '0,0',
#   'tmin': '5,6',
#   'tmax': '14,8',
#   'sol': '9,8'},
#  {'fecha': '2016-02-17',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '10,1',
#   'prec': '0,0',
#   'tmin': '4,2',
#   'tmax': '16,0',
#   'sol': '9,6'},
#  {'fecha': '2016-02-18',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,8',
#   'prec': 'Ip',
#   'tmin': '9,2',
#   'tmax': '16,5',
#   'sol': '3,0'},
#  {'fecha': '2016-02-19',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,9',
#   'prec': '0,0',
#   'tmin': '8,5',
#   'tmax': '15,3',
#   'sol': '5,2'},
#  {'fecha': '2016-02-20',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,0',
#   'prec': '0,0',
#   'tmin': '5,2',
#   'tmax': '16,7',
#   'sol': '8,8'},
#  {'fecha': '2016-02-21',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,5',
#   'prec': 'Ip',
#   'tmin': '5,2',
#   'tmax': '17,8',
#   'sol': '7,2'},
#  {'fecha': '2016-02-22',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,7',
#   'prec': '0,0',
#   'tmin': '11,0',
#   'tmax': '22,4',
#   'sol': '7,1'},
#  {'fecha': '2016-02-23',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,4',
#   'prec': '0,0',
#   'tmin': '11,4',
#   'tmax': '23,5',
#   'sol': '8,5'},
#  {'fecha': '2016-02-24',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,8',
#   'prec': '0,0',
#   'tmin': '10,0',
#   'tmax': '21,5',
#   'sol': '8,2'},
#  {'fecha': '2016-02-25',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,2',
#   'prec': '0,0',
#   'tmin': '12,1',
#   'tmax': '22,3',
#   'sol': '7,8'},
#  {'fecha': '2016-02-26',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,5',
#   'prec': '0,9',
#   'tmin': '10,4',
#   'tmax': '18,6',
#   'sol': '3,1'},
#  {'fecha': '2016-02-27',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '10,4',
#   'prec': '0,0',
#   'tmin': '8,6',
#   'tmax': '12,1',
#   'sol': '0,0'},
#  {'fecha': '2016-02-28',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,0',
#   'prec': '0,0',
#   'tmin': '9,2',
#   'tmax': '16,8',
#   'sol': '5,6'},
#  {'fecha': '2016-02-29',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,7',
#   'prec': '0,0',
#   'tmin': '11,0',
#   'tmax': '20,4',
#   'sol': '9,1'},
#  {'fecha': '2016-03-01',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,0',
#   'prec': '0,0',
#   'tmin': '7,0',
#   'tmax': '21,0',
#   'sol': '9,4'},
#  {'fecha': '2016-03-02',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,2',
#   'prec': '0,0',
#   'tmin': '11,3',
#   'tmax': '27,0',
#   'sol': '9,3'},
#  {'fecha': '2016-03-03',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,7',
#   'prec': '0,0',
#   'tmin': '10,4',
#   'tmax': '23,0',
#   'sol': '9,0'},
#  {'fecha': '2016-03-04',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,5',
#   'prec': '0,0',
#   'tmin': '10,5',
#   'tmax': '24,5',
#   'sol': '8,0'},
#  {'fecha': '2016-03-05',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,2',
#   'prec': '0,0',
#   'tmin': '10,5',
#   'tmax': '20,0',
#   'sol': '10,1'},
#  {'fecha': '2016-03-06',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,8',
#   'prec': '0,0',
#   'tmin': '12,6',
#   'tmax': '16,9',
#   'sol': '7,2'},
#  {'fecha': '2016-03-07',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,2',
#   'prec': '2,8',
#   'tmin': '9,6',
#   'tmax': '12,8',
#   'sol': '0,8'},
#  {'fecha': '2016-03-08',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,4',
#   'prec': '0,0',
#   'tmin': '5,9',
#   'tmax': '17,0',
#   'sol': '10,4'},
#  {'fecha': '2016-03-09',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,6',
#   'prec': '0,2',
#   'tmin': '7,1',
#   'tmax': '18,0',
#   'sol': '1,9'},
#  {'fecha': '2016-03-10',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '10,8',
#   'prec': '0,0',
#   'tmin': '9,1',
#   'tmax': '12,5',
#   'sol': '5,7'},
#  {'fecha': '2016-03-11',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,5',
#   'prec': '0,0',
#   'tmin': '7,0',
#   'tmax': '18,0',
#   'sol': '10,5'},
#  {'fecha': '2016-03-12',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,8',
#   'prec': '0,0',
#   'tmin': '7,0',
#   'tmax': '16,5',
#   'sol': '10,4'},
#  {'fecha': '2016-03-13',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,0',
#   'prec': '0,0',
#   'tmin': '6,5',
#   'tmax': '15,6',
#   'sol': '9,5'},
#  {'fecha': '2016-03-14',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,8',
#   'prec': '0,0',
#   'tmin': '10,4',
#   'tmax': '15,3',
#   'sol': '2,3'},
#  {'fecha': '2016-03-15',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,2',
#   'prec': '0,0',
#   'tmin': '10,5',
#   'tmax': '16,0',
#   'sol': '2,4'},
#  {'fecha': '2016-03-16',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,6',
#   'prec': '0,0',
#   'tmin': '8,2',
#   'tmax': '21,0',
#   'sol': '9,3'},
#  {'fecha': '2016-03-17',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,8',
#   'prec': '0,0',
#   'tmin': '10,5',
#   'tmax': '15,0',
#   'sol': '5,3'},
#  {'fecha': '2016-03-18',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,0',
#   'prec': '0,8',
#   'tmin': '11,5',
#   'tmax': '16,6',
#   'sol': '2,4'},
#  {'fecha': '2016-03-19',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,4',
#   'prec': '2,2',
#   'tmin': '11,5',
#   'tmax': '15,4',
#   'sol': '0,0'},
#  {'fecha': '2016-03-20',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,4',
#   'prec': '0,0',
#   'tmin': '8,9',
#   'tmax': '18,0',
#   'sol': '8,4'},
#  {'fecha': '2016-03-21',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,1',
#   'prec': '0,4',
#   'tmin': '11,0',
#   'tmax': '17,2',
#   'sol': '3,4'},
#  {'fecha': '2016-03-22',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,4',
#   'prec': 'Ip',
#   'tmin': '11,4',
#   'tmax': '19,5',
#   'sol': '1,6'},
#  {'fecha': '2016-03-23',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,7',
#   'prec': '0,0',
#   'tmin': '10,0',
#   'tmax': '21,4',
#   'sol': '10,7'},
#  {'fecha': '2016-03-24',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,6',
#   'prec': '0,0',
#   'tmin': '9,6',
#   'tmax': '21,5',
#   'sol': '10,7'},
#  {'fecha': '2016-03-25',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '18,6',
#   'prec': '0,0',
#   'tmin': '9,1',
#   'tmax': '28,0',
#   'sol': '8,2'},
#  {'fecha': '2016-03-26',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '18,8',
#   'prec': '0,0',
#   'tmin': '11,5',
#   'tmax': '26,0',
#   'sol': '5,8'},
#  {'fecha': '2016-03-27',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '20,7',
#   'prec': '0,0',
#   'tmin': '16,0',
#   'tmax': '25,4'},
#  {'fecha': '2016-03-28',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,2',
#   'prec': '0,0',
#   'tmin': '14,0',
#   'tmax': '24,5',
#   'sol': '0,8'},
#  {'fecha': '2016-03-29',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '20,9',
#   'prec': '0,0',
#   'tmin': '14,8',
#   'tmax': '27,0',
#   'sol': '8,5'},
#  {'fecha': '2016-03-30',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,4',
#   'prec': '0,0',
#   'tmin': '11,3',
#   'tmax': '19,4'},
#  {'fecha': '2016-03-31',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,7',
#   'prec': '0,0',
#   'tmin': '11,9',
#   'tmax': '21,5'},
#  {'fecha': '2016-04-01',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,4',
#   'prec': '0,0',
#   'tmin': '9,5',
#   'tmax': '17,4',
#   'sol': '10,1'},
#  {'fecha': '2016-04-02',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,6',
#   'prec': '0,0',
#   'tmin': '8,3',
#   'tmax': '21,0',
#   'sol': '10,9'},
#  {'fecha': '2016-04-03',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,8',
#   'prec': '1,3',
#   'tmin': '10,0',
#   'tmax': '19,5',
#   'sol': '10,3'},
#  {'fecha': '2016-04-04',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,7',
#   'prec': '11,6',
#   'tmin': '12,9',
#   'tmax': '18,5',
#   'sol': '1,2'},
#  {'fecha': '2016-04-05',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,4',
#   'prec': '3,0',
#   'tmin': '12,2',
#   'tmax': '16,5',
#   'sol': '0,0'},
#  {'fecha': '2016-04-06',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,6',
#   'prec': '0,0',
#   'tmin': '12,5',
#   'tmax': '22,8',
#   'sol': '8,0'},
#  {'fecha': '2016-04-07',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,2',
#   'prec': '1,5',
#   'tmin': '11,4',
#   'tmax': '21,1',
#   'sol': '10,9'},
#  {'fecha': '2016-04-08',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,8',
#   'prec': '0,0',
#   'tmin': '9,4',
#   'tmax': '18,3',
#   'sol': '9,4'},
#  {'fecha': '2016-04-09',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,6',
#   'prec': '0,0',
#   'tmin': '9,6',
#   'tmax': '25,5',
#   'sol': '11,2'},
#  {'fecha': '2016-04-10',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,6',
#   'prec': '0,0',
#   'tmin': '11,4',
#   'tmax': '21,8',
#   'sol': '9,8'},
#  {'fecha': '2016-04-11',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,8',
#   'prec': '0,0',
#   'tmin': '13,1',
#   'tmax': '22,6',
#   'sol': '9,8'},
#  {'fecha': '2016-04-12',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,9',
#   'prec': '0,0',
#   'tmin': '13,0',
#   'tmax': '22,8',
#   'sol': '10,9'},
#  {'fecha': '2016-04-13',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,8',
#   'prec': '0,0',
#   'tmin': '15,1',
#   'tmax': '24,6',
#   'sol': '10,9'},
#  {'fecha': '2016-04-14',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,4',
#   'prec': '0,0',
#   'tmin': '13,3',
#   'tmax': '25,5',
#   'sol': '11,2'},
#  {'fecha': '2016-04-15',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,2',
#   'prec': '0,0',
#   'tmin': '12,3',
#   'tmax': '20,0',
#   'sol': '9,9'},
#  {'fecha': '2016-04-16',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '21,5',
#   'prec': '0,0',
#   'tmin': '15,0',
#   'tmax': '28,0',
#   'sol': '9,5'},
#  {'fecha': '2016-04-17',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '22,4',
#   'prec': '0,0',
#   'tmin': '17,0',
#   'tmax': '27,9',
#   'sol': '10,1'},
#  {'fecha': '2016-04-18',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,5',
#   'prec': '0,0',
#   'tmin': '15,0',
#   'tmax': '20,0',
#   'sol': '10,1'},
#  {'fecha': '2016-04-19',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,2',
#   'prec': '0,0',
#   'tmin': '15,0',
#   'tmax': '19,5',
#   'sol': '5,9'},
#  {'fecha': '2016-04-20',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,7',
#   'prec': '0,0',
#   'tmin': '13,9',
#   'tmax': '19,5',
#   'sol': '0,0'},
#  {'fecha': '2016-04-21',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '20,2',
#   'prec': '0,0',
#   'tmin': '14,5',
#   'tmax': '25,8',
#   'sol': '10,0'},
#  {'fecha': '2016-04-22',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,6',
#   'prec': '0,0',
#   'tmin': '14,6',
#   'tmax': '20,5',
#   'sol': '2,4'},
#  {'fecha': '2016-04-23',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,0',
#   'prec': '0,3',
#   'tmin': '12,0',
#   'tmax': '25,9',
#   'sol': '10,5'},
#  {'fecha': '2016-04-24',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '20,0',
#   'prec': '0,0',
#   'tmin': '14,1',
#   'tmax': '25,8',
#   'sol': '11,7'},
#  {'fecha': '2016-04-25',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,0',
#   'prec': '0,0',
#   'tmin': '11,8',
#   'tmax': '18,1',
#   'sol': '10,7'},
#  {'fecha': '2016-04-26',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,0',
#   'prec': '0,0',
#   'tmin': '11,3',
#   'tmax': '20,6',
#   'sol': '10,0'},
#  {'fecha': '2016-04-27',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,8',
#   'prec': '0,0',
#   'tmin': '13,2',
#   'tmax': '20,5',
#   'sol': '3,0'},
#  {'fecha': '2016-04-28',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,8',
#   'prec': '0,0',
#   'tmin': '14,3',
#   'tmax': '17,2',
#   'sol': '0,8'},
#  {'fecha': '2016-04-29',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,2',
#   'prec': '1,0',
#   'tmin': '13,1',
#   'tmax': '17,2',
#   'sol': '0,0'},
#  {'fecha': '2016-04-30',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,6',
#   'prec': '0,0',
#   'tmin': '13,5',
#   'tmax': '19,6',
#   'sol': '8,0'},
#  {'fecha': '2016-05-01',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,0',
#   'prec': '0,0',
#   'tmin': '11,4',
#   'tmax': '20,5',
#   'sol': '11,6'},
#  {'fecha': '2016-05-02',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,9',
#   'prec': '0,3',
#   'tmin': '10,3',
#   'tmax': '21,5',
#   'sol': '10,9'},
#  {'fecha': '2016-05-03',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,5',
#   'prec': '0,0',
#   'tmin': '11,5',
#   'tmax': '23,5',
#   'sol': '10,5'},
#  {'fecha': '2016-05-04',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,6',
#   'prec': '0,0',
#   'tmin': '11,3',
#   'tmax': '22,0',
#   'sol': '10,9'},
#  {'fecha': '2016-05-05',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,8',
#   'prec': '0,0',
#   'tmin': '12,0',
#   'tmax': '19,5',
#   'sol': '0,4'},
#  {'fecha': '2016-05-06',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,0',
#   'prec': '0,0',
#   'tmin': '14,1',
#   'tmax': '20,0',
#   'sol': '4,0'},
#  {'fecha': '2016-05-07',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '18,5',
#   'prec': '0,3',
#   'tmin': '15,5',
#   'tmax': '21,5',
#   'sol': '0,0'},
#  {'fecha': '2016-05-08',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,1',
#   'prec': '14,2',
#   'tmin': '16,0',
#   'tmax': '18,2',
#   'sol': '0,0'},
#  {'fecha': '2016-05-09',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,8',
#   'prec': '6,7',
#   'tmin': '15,2',
#   'tmax': '18,5',
#   'sol': '1,3'},
#  {'fecha': '2016-05-10',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,6',
#   'prec': '1,6',
#   'tmin': '12,2',
#   'tmax': '19,1',
#   'sol': '0,0'},
#  {'fecha': '2016-05-11',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '20,1',
#   'prec': '4,0',
#   'tmin': '14,2',
#   'tmax': '26,0',
#   'sol': '12,0'},
#  {'fecha': '2016-05-12',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,1',
#   'prec': '0,0',
#   'tmin': '14,0',
#   'tmax': '24,2',
#   'sol': '6,0'},
#  {'fecha': '2016-05-13',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,8',
#   'prec': '0,0',
#   'tmin': '15,0',
#   'tmax': '24,5',
#   'sol': '7,5'},
#  {'fecha': '2016-05-14',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '21,0',
#   'prec': '0,0',
#   'tmin': '14,5',
#   'tmax': '27,5',
#   'sol': '10,2'},
#  {'fecha': '2016-05-15',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '20,6',
#   'prec': '0,0',
#   'tmin': '17,1',
#   'tmax': '24,0',
#   'sol': '11,0'},
#  {'fecha': '2016-05-16',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '18,6',
#   'prec': '0,0',
#   'tmin': '15,0',
#   'tmax': '22,3',
#   'sol': '10,6'},
#  {'fecha': '2016-05-17',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,8',
#   'prec': '0,0',
#   'tmin': '14,0',
#   'tmax': '21,5',
#   'sol': '4,9'},
#  {'fecha': '2016-05-18',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,4',
#   'prec': '0,8',
#   'tmin': '15,5',
#   'tmax': '23,3',
#   'sol': '7,9'},
#  {'fecha': '2016-05-19',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,2',
#   'prec': '0,0',
#   'tmin': '15,8',
#   'tmax': '22,6',
#   'sol': '11,6'},
#  {'fecha': '2016-05-20',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,2',
#   'prec': '0,0',
#   'tmin': '15,0',
#   'tmax': '23,4',
#   'sol': '11,7'},
#  {'fecha': '2016-05-21',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,1',
#   'prec': '0,0',
#   'tmin': '15,4',
#   'tmax': '22,8',
#   'sol': '11,3'},
#  {'fecha': '2016-05-22',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,8',
#   'prec': '0,0',
#   'tmin': '16,2',
#   'tmax': '31,5',
#   'sol': '10,7'},
#  {'fecha': '2016-05-23',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '18,5',
#   'prec': '0,0',
#   'tmin': '16,0',
#   'tmax': '21,0',
#   'sol': '11,5'},
#  {'fecha': '2016-05-24',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '18,8',
#   'prec': '0,0',
#   'tmin': '15,5',
#   'tmax': '22,0',
#   'sol': '10,5'},
#  {'fecha': '2016-05-25',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,8',
#   'prec': '0,0',
#   'tmin': '16,5',
#   'tmax': '23,2',
#   'sol': '10,5'},
#  {'fecha': '2016-05-26',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '21,2',
#   'prec': '0,0',
#   'tmin': '18,5',
#   'tmax': '23,9',
#   'sol': '8,7'},
#  {'fecha': '2016-05-27',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '20,6',
#   'prec': '0,0',
#   'tmin': '18,4',
#   'tmax': '22,7',
#   'sol': '8,8'},
#  {'fecha': '2016-05-28',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,7',
#   'prec': '0,0',
#   'tmin': '17,0',
#   'tmax': '32,4',
#   'sol': '8,6'},
#  {'fecha': '2016-05-29',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,8',
#   'prec': '0,0',
#   'tmin': '18,5',
#   'tmax': '29,0',
#   'sol': '11,6'},
#  {'fecha': '2016-05-30',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,8',
#   'prec': '0,0',
#   'tmin': '18,0',
#   'tmax': '21,5',
#   'sol': '11,5'},
#  {'fecha': '2016-05-31',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '20,1',
#   'prec': '0,0',
#   'tmin': '15,5',
#   'tmax': '24,7',
#   'sol': '11,5'},
#  {'fecha': '2016-06-01',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '20,2',
#   'prec': '0,0',
#   'tmin': '15,6',
#   'tmax': '24,7',
#   'sol': '11,6'},
#  {'fecha': '2016-06-02',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '19,8',
#   'prec': '0,0',
#   'tmin': '15,5',
#   'tmax': '24,0',
#   'sol': '11,0'},
#  {'fecha': '2016-06-03',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '20,9',
#   'prec': '0,0',
#   'tmin': '17,8',
#   'tmax': '24,0',
#   'sol': '10,4'},
#  {'fecha': '2016-06-04',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '21,0',
#   'prec': '1,2',
#   'tmin': '17,5',
#   'tmax': '24,5',
#   'sol': '3,2'},
#  {'fecha': '2016-06-05',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '21,2',
#   'prec': '0,0',
#   'tmin': '16,9',
#   'tmax': '25,4',
#   'sol': '10,0'},
#  {'fecha': '2016-06-06',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '21,9',
#   'prec': '0,0',
#   'tmin': '17,6',
#   'tmax': '26,2',
#   'sol': '11,4'},
#  {'fecha': '2016-06-07',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '22,2',
#   'prec': '0,0',
#   'tmin': '18,5',
#   'tmax': '26,0',
#   'sol': '11,3'},
#  {'fecha': '2016-06-08',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,2',
#   'prec': '0,0',
#   'tmin': '18,6',
#   'tmax': '27,7',
#   'sol': '11,5'},
#  {'fecha': '2016-06-09',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,0',
#   'prec': '0,0',
#   'tmin': '19,1',
#   'tmax': '26,8',
#   'sol': '10,3'},
#  {'fecha': '2016-06-10',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,2',
#   'prec': '0,0',
#   'tmin': '21,5',
#   'tmax': '27,0',
#   'sol': '9,7'},
#  {'fecha': '2016-06-11',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,6',
#   'prec': '0,0',
#   'tmin': '22,0',
#   'tmax': '27,1',
#   'sol': '7,7'},
#  {'fecha': '2016-06-12',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,8',
#   'prec': '0,0',
#   'tmin': '20,2',
#   'tmax': '27,5',
#   'sol': '10,8'},
#  {'fecha': '2016-06-13',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '25,8',
#   'prec': '0,0',
#   'tmin': '21,0',
#   'tmax': '30,5',
#   'sol': '11,4'},
#  {'fecha': '2016-06-14',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,3',
#   'prec': '0,0',
#   'tmin': '22,4',
#   'tmax': '26,2',
#   'sol': '11,3'},
#  {'fecha': '2016-06-15',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,6',
#   'prec': '0,0',
#   'tmin': '20,4',
#   'tmax': '32,8',
#   'sol': '9,2'},
#  {'fecha': '2016-06-16',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,4',
#   'prec': '0,0',
#   'tmin': '19,5',
#   'tmax': '27,4',
#   'sol': '8,9'},
#  {'fecha': '2016-06-17',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '22,6',
#   'prec': '0,0',
#   'tmin': '17,8',
#   'tmax': '27,5',
#   'sol': '10,4'},
#  {'fecha': '2016-06-18',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '21,5',
#   'prec': '0,0',
#   'tmin': '18,5',
#   'tmax': '24,5',
#   'sol': '9,8'},
#  {'fecha': '2016-06-19',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '20,4',
#   'prec': '0,0',
#   'tmin': '17,0',
#   'tmax': '23,9',
#   'sol': '10,3'},
#  {'fecha': '2016-06-20',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '20,6',
#   'prec': '0,0',
#   'tmin': '15,7',
#   'tmax': '25,5',
#   'sol': '11,5'},
#  {'fecha': '2016-06-21',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '22,2',
#   'prec': '0,0',
#   'tmin': '17,5',
#   'tmax': '27,0',
#   'sol': '11,1'},
#  {'fecha': '2016-06-22',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '22,2',
#   'prec': '0,0',
#   'tmin': '17,5',
#   'tmax': '27,0',
#   'sol': '11,0'},
#  {'fecha': '2016-06-23',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,6',
#   'prec': '0,0',
#   'tmin': '19,0',
#   'tmax': '28,1',
#   'sol': '11,4'},
#  {'fecha': '2016-06-24',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '22,9',
#   'prec': '0,0',
#   'tmin': '19,1',
#   'tmax': '26,7',
#   'sol': '10,4'},
#  {'fecha': '2016-06-25',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,8',
#   'prec': '0,0',
#   'tmin': '20,8',
#   'tmax': '26,8',
#   'sol': '9,3'},
#  {'fecha': '2016-06-26',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,0',
#   'prec': '0,0',
#   'tmin': '21,6',
#   'tmax': '26,5',
#   'sol': '11,3'},
#  {'fecha': '2016-06-27',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,2',
#   'prec': '0,0',
#   'tmin': '19,8',
#   'tmax': '26,7',
#   'sol': '7,8'},
#  {'fecha': '2016-06-28',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,7',
#   'prec': 'Ip',
#   'tmin': '19,6',
#   'tmax': '27,8',
#   'sol': '7,3'},
#  {'fecha': '2016-06-29',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '25,3',
#   'prec': 'Ip',
#   'tmin': '21,8',
#   'tmax': '28,8',
#   'sol': '7,7'},
#  {'fecha': '2016-06-30',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,6',
#   'prec': '0,7',
#   'tmin': '22,0',
#   'tmax': '27,3'},
#  {'fecha': '2016-07-01',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,8',
#   'prec': '0,0',
#   'tmin': '21,5',
#   'tmax': '28,1',
#   'sol': '11,8'},
#  {'fecha': '2016-07-02',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,8',
#   'prec': '0,0',
#   'tmin': '21,5',
#   'tmax': '28,2',
#   'sol': '11,2'},
#  {'fecha': '2016-07-03',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '25,3',
#   'prec': '0,0',
#   'tmin': '22,6',
#   'tmax': '28,0',
#   'sol': '11,1'},
#  {'fecha': '2016-07-04',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,7',
#   'prec': '0,0',
#   'tmin': '21,4',
#   'tmax': '28,0',
#   'sol': '10,8'},
#  {'fecha': '2016-07-05',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,4',
#   'prec': '0,0',
#   'tmin': '21,6',
#   'tmax': '31,1',
#   'sol': '10,6'},
#  {'fecha': '2016-07-06',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,2',
#   'prec': '0,0',
#   'tmin': '21,5',
#   'tmax': '31,0',
#   'sol': '11,4'},
#  {'fecha': '2016-07-07',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '25,7',
#   'prec': '0,0',
#   'tmin': '21,6',
#   'tmax': '29,8',
#   'sol': '2,0'},
#  {'fecha': '2016-07-08',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '27,0',
#   'prec': '0,0',
#   'tmin': '22,5',
#   'tmax': '31,5',
#   'sol': '10,9'},
#  {'fecha': '2016-07-09',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '27,0',
#   'prec': '0,0',
#   'tmin': '23,1',
#   'tmax': '30,9',
#   'sol': '11,5'},
#  {'fecha': '2016-07-10',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '28,0',
#   'prec': '0,0',
#   'tmin': '23,1',
#   'tmax': '33,0',
#   'sol': '11,5'},
#  {'fecha': '2016-07-11',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,6',
#   'prec': '0,0',
#   'tmin': '23,0',
#   'tmax': '30,3',
#   'sol': '11,3'},
#  {'fecha': '2016-07-12',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,4',
#   'prec': '0,0',
#   'tmin': '22,7',
#   'tmax': '30,0',
#   'sol': '11,3'},
#  {'fecha': '2016-07-13',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '25,0',
#   'prec': '0,0',
#   'tmin': '24,4',
#   'tmax': '25,6',
#   'sol': '3,1'},
#  {'fecha': '2016-07-14',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,2',
#   'prec': '0,0',
#   'tmin': '22,0',
#   'tmax': '26,5',
#   'sol': '7,6'},
#  {'fecha': '2016-07-15',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,8',
#   'prec': '0,0',
#   'tmin': '21,2',
#   'tmax': '26,5',
#   'sol': '8,5'},
#  {'fecha': '2016-07-16',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,2',
#   'prec': '0,0',
#   'tmin': '20,5',
#   'tmax': '27,8',
#   'sol': '11,5'},
#  {'fecha': '2016-07-17',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,2',
#   'prec': '0,0',
#   'tmin': '20,0',
#   'tmax': '26,5',
#   'sol': '11,6'},
#  {'fecha': '2016-07-18',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,8',
#   'prec': '0,0',
#   'tmin': '19,7',
#   'tmax': '28,0',
#   'sol': '11,6'},
#  {'fecha': '2016-07-19',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,0',
#   'prec': '0,0',
#   'tmin': '20,0',
#   'tmax': '28,1',
#   'sol': '10,3'},
#  {'fecha': '2016-07-20',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,3',
#   'prec': 'Ip',
#   'tmin': '22,6',
#   'tmax': '30,0',
#   'sol': '3,8'},
#  {'fecha': '2016-07-21',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,3',
#   'prec': '0,0',
#   'tmin': '23,1',
#   'tmax': '29,5',
#   'sol': '10,7'},
#  {'fecha': '2016-07-22',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '25,6',
#   'prec': 'Ip',
#   'tmin': '22,0',
#   'tmax': '29,3',
#   'sol': '8,0'},
#  {'fecha': '2016-07-23',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '25,7',
#   'prec': '0,0',
#   'tmin': '22,0',
#   'tmax': '29,4',
#   'sol': '11,3'},
#  {'fecha': '2016-07-24',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '25,5',
#   'prec': '0,0',
#   'tmin': '21,2',
#   'tmax': '29,8',
#   'sol': '11,7'},
#  {'fecha': '2016-07-25',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,4',
#   'prec': '0,0',
#   'tmin': '21,8',
#   'tmax': '31,0',
#   'sol': '11,9'},
#  {'fecha': '2016-07-26',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,6',
#   'prec': '0,0',
#   'tmin': '22,0',
#   'tmax': '31,1',
#   'sol': '11,5'},
#  {'fecha': '2016-07-27',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '27,1',
#   'prec': '0,0',
#   'tmin': '23,7',
#   'tmax': '30,5',
#   'sol': '8,6'},
#  {'fecha': '2016-07-28',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,0',
#   'prec': '0,0',
#   'tmin': '21,8',
#   'tmax': '30,2',
#   'sol': '11,7'},
#  {'fecha': '2016-07-29',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,4',
#   'prec': '0,0',
#   'tmin': '22,3',
#   'tmax': '30,6',
#   'sol': '11,4'},
#  {'fecha': '2016-07-30',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,8',
#   'prec': '0,0',
#   'tmin': '22,6',
#   'tmax': '30,9',
#   'sol': '11,4'},
#  {'fecha': '2016-07-31',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '28,1',
#   'prec': '0,0',
#   'tmin': '24,0',
#   'tmax': '32,2',
#   'sol': '9,7'},
#  {'fecha': '2016-08-01',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '27,3',
#   'prec': '0,0',
#   'tmin': '25,6',
#   'tmax': '29,0',
#   'sol': '11,5'},
#  {'fecha': '2016-08-02',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '25,6',
#   'prec': '0,0',
#   'tmin': '22,5',
#   'tmax': '28,8',
#   'sol': '10,9'},
#  {'fecha': '2016-08-03',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,2',
#   'prec': '0,0',
#   'tmin': '23,0',
#   'tmax': '29,4',
#   'sol': '11,4'},
#  {'fecha': '2016-08-04',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,5',
#   'prec': '0,0',
#   'tmin': '23,5',
#   'tmax': '29,5',
#   'sol': '11,3'},
#  {'fecha': '2016-08-05',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '25,9',
#   'prec': '1,0',
#   'tmin': '24,0',
#   'tmax': '27,8',
#   'sol': '6,8'},
#  {'fecha': '2016-08-06',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '25,6',
#   'prec': '0,0',
#   'tmin': '22,5',
#   'tmax': '28,8',
#   'sol': '11,7'},
#  {'fecha': '2016-08-07',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,0',
#   'prec': '0,0',
#   'tmin': '21,6',
#   'tmax': '30,5',
#   'sol': '11,8'},
#  {'fecha': '2016-08-08',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,8',
#   'prec': '0,0',
#   'tmin': '21,5',
#   'tmax': '32,2',
#   'sol': '11,8'},
#  {'fecha': '2016-08-09',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '27,0',
#   'prec': '0,2',
#   'tmin': '22,4',
#   'tmax': '31,5',
#   'sol': '11,8'},
#  {'fecha': '2016-08-10',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,8',
#   'prec': '27,7',
#   'tmin': '23,6',
#   'tmax': '26,0',
#   'sol': '4,8'},
#  {'fecha': '2016-08-11',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '23,2',
#   'prec': '0,0',
#   'tmin': '19,6',
#   'tmax': '26,9',
#   'sol': '9,8'},
#  {'fecha': '2016-08-12',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,8',
#   'prec': '0,0',
#   'tmin': '22,0',
#   'tmax': '27,6',
#   'sol': '11,1'},
#  {'fecha': '2016-08-13',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,2',
#   'prec': '0,0',
#   'tmin': '19,8',
#   'tmax': '28,7',
#   'sol': '11,6'},
#  {'fecha': '2016-08-14',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,9',
#   'prec': '0,0',
#   'tmin': '21,1',
#   'tmax': '28,7',
#   'sol': '12,0'},
#  {'fecha': '2016-08-15',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '24,2',
#   'prec': '1,3',
#   'tmin': '19,6',
#   'tmax': '28,7',
#   'sol': '9,6'},
#  {'fecha': '2016-08-16',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,0',
#   'prec': '0,0',
#   'tmin': '22,2',
#   'tmax': '29,9',
#   'sol': '2,9'},
#  {'fecha': '2016-08-17',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,5',
#   'prec': '0,0',
#   'tmin': '22,3',
#   'tmax': '30,7',
#   'sol': '10,9'},
#  {'fecha': '2016-08-18',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,4',
#   'prec': '0,0',
#   'tmin': '23,2',
#   'tmax': '29,5',
#   'sol': '11,2'},
#  {'fecha': '2016-08-19',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '26,4',
#   'prec': '0,0',
#   'tmin': '22,8',
#   'tmax': '29,9',
# ...
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,2',
#   'prec': '0,0',
#   'tmin': '7,9',
#   'tmax': '16,5',
#   'sol': '7,7'},
#  {'fecha': '2016-12-15',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,2',
#   'prec': '0,3',
#   'tmin': '8,5',
#   'tmax': '15,8',
#   'sol': '0,8'},
#  {'fecha': '2016-12-16',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,2',
#   'prec': '46,2',
#   'tmin': '9,2',
#   'tmax': '15,2',
#   'sol': '0,0'},
#  {'fecha': '2016-12-17',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,0',
#   'prec': '13,1',
#   'tmin': '12,0',
#   'tmax': '16,0',
#   'sol': '0,0'},
#  {'fecha': '2016-12-18',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,0',
#   'prec': '74,0',
#   'tmin': '10,5',
#   'tmax': '13,6',
#   'sol': '0,0'},
#  {'fecha': '2016-12-19',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '10,6',
#   'prec': '4,1',
#   'tmin': '10,2',
#   'tmax': '10,9',
#   'sol': '0,0'},
#  {'fecha': '2016-12-20',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,7',
#   'prec': '0,2',
#   'tmin': '9,9',
#   'tmax': '17,5',
#   'sol': '6,8'},
#  {'fecha': '2016-12-21',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,4',
#   'prec': '0,0',
#   'tmin': '6,0',
#   'tmax': '16,7',
#   'sol': '4,5'},
#  {'fecha': '2016-12-22',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,0',
#   'prec': '0,1',
#   'tmin': '8,2',
#   'tmax': '19,8',
#   'sol': '7,2'},
#  {'fecha': '2016-12-23',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,2',
#   'prec': '0,0',
#   'tmin': '9,0',
#   'tmax': '19,4',
#   'sol': '8,4'},
#  {'fecha': '2016-12-24',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,0',
#   'prec': '0,0',
#   'tmin': '8,8',
#   'tmax': '19,2',
#   'sol': '8,4'},
#  {'fecha': '2016-12-25',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,7',
#   'prec': '0,0',
#   'tmin': '8,1',
#   'tmax': '19,3',
#   'sol': '8,3'},
#  {'fecha': '2016-12-26',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,1',
#   'prec': '0,0',
#   'tmin': '6,7',
#   'tmax': '17,5',
#   'sol': '7,5'},
#  {'fecha': '2016-12-27',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,2',
#   'prec': '0,0',
#   'tmin': '7,1',
#   'tmax': '17,2',
#   'sol': '6,5'},
#  {'fecha': '2016-12-28',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,6',
#   'prec': '0,0',
#   'tmin': '6,3',
#   'tmax': '17,0',
#   'sol': '7,1'},
#  {'fecha': '2016-12-29',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,4',
#   'prec': '0,0',
#   'tmin': '7,1',
#   'tmax': '17,8',
#   'sol': '8,5'},
#  {'fecha': '2016-12-30',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '10,2',
#   'prec': '0,0',
#   'tmin': '4,4',
#   'tmax': '16,1',
#   'sol': '6,7'},
#  {'fecha': '2016-12-31',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,6',
#   'prec': '0,0',
#   'tmin': '7,5',
#   'tmax': '15,8',
#   'sol': '4,1'},
#  {'fecha': '2017-01-01',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,0',
#   'prec': '0,0',
#   'tmin': '5,8',
#   'tmax': '16,1',
#   'sol': '8,4'},
#  {'fecha': '2017-01-02',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '9,0',
#   'prec': '0,0',
#   'tmin': '3,8',
#   'tmax': '14,2',
#   'sol': '7,5'},
#  {'fecha': '2017-01-03',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '10,0',
#   'prec': '0,0',
#   'tmin': '4,1',
#   'tmax': '16,0',
#   'sol': '5,5'},
#  {'fecha': '2017-01-04',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,0',
#   'prec': '0,0',
#   'tmin': '5,8',
#   'tmax': '20,1',
#   'sol': '8,6'},
#  {'fecha': '2017-01-05',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,2',
#   'prec': '0,0',
#   'tmin': '6,8',
#   'tmax': '17,5',
#   'sol': '8,7'},
#  {'fecha': '2017-01-06',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '10,8',
#   'prec': '0,0',
#   'tmin': '5,5',
#   'tmax': '16,1',
#   'sol': '8,6'},
#  {'fecha': '2017-01-07',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '10,2',
#   'prec': '0,0',
#   'tmin': '5,4',
#   'tmax': '15,1',
#   'sol': '8,6'},
#  {'fecha': '2017-01-08',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '10,4',
#   'prec': '0,0',
#   'tmin': '4,1',
#   'tmax': '16,7',
#   'sol': '8,7'},
#  {'fecha': '2017-01-09',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '10,0',
#   'prec': '0,0',
#   'tmin': '4,2',
#   'tmax': '15,9',
#   'sol': '7,4'},
#  {'fecha': '2017-01-10',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '10,0',
#   'prec': '0,0',
#   'tmin': '4,5',
#   'tmax': '15,6',
#   'sol': '0,3'},
#  {'fecha': '2017-01-11',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,2',
#   'prec': '0,0',
#   'tmin': '8,3',
#   'tmax': '16,1',
#   'sol': '8,6'},
#  {'fecha': '2017-01-12',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,0',
#   'prec': '0,0',
#   'tmin': '6,0',
#   'tmax': '22,0',
#   'sol': '8,2'},
#  {'fecha': '2017-01-13',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,4',
#   'prec': '0,0',
#   'tmin': '11,0',
#   'tmax': '17,9',
#   'sol': '7,8'},
#  {'fecha': '2017-01-14',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,2',
#   'prec': '0,0',
#   'tmin': '7,5',
#   'tmax': '14,8',
#   'sol': '8,1'},
#  {'fecha': '2017-01-15',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,4',
#   'prec': '0,0',
#   'tmin': '6,3',
#   'tmax': '16,5',
#   'sol': '5,8'},
#  {'fecha': '2017-01-16',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,2',
#   'prec': '0,0',
#   'tmin': '8,0',
#   'tmax': '18,4',
#   'sol': '8,0'},
#  {'fecha': '2017-01-17',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '8,0',
#   'prec': 'Ip',
#   'tmin': '4,0',
#   'tmax': '12,0',
#   'sol': '3,8'},
#  {'fecha': '2017-01-18',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '5,8',
#   'prec': '0,3',
#   'tmin': '0,9',
#   'tmax': '10,8',
#   'sol': '6,8'},
#  {'fecha': '2017-01-19',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '7,5',
#   'prec': '76,6',
#   'tmin': '4,4',
#   'tmax': '10,6',
#   'sol': '0,0'},
#  {'fecha': '2017-01-20',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '7,1',
#   'prec': '66,5',
#   'tmin': '4,8',
#   'tmax': '9,4',
#   'sol': '0,0'},
#  {'fecha': '2017-01-21',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '9,4',
#   'prec': '1,3',
#   'tmin': '6,5',
#   'tmax': '12,4',
#   'sol': '0,0'},
#  {'fecha': '2017-01-22',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,8',
#   'prec': '0,4',
#   'tmin': '9,6',
#   'tmax': '16,1',
#   'sol': '0,0'},
#  {'fecha': '2017-01-23',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,2',
#   'prec': '0,2',
#   'tmin': '8,2',
#   'tmax': '16,2',
#   'sol': '3,1'},
#  {'fecha': '2017-01-24',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,2',
#   'prec': '0,0',
#   'tmin': '6,8',
#   'tmax': '15,6',
#   'sol': '3,8'},
#  {'fecha': '2017-01-25',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,4',
#   'prec': '0,0',
#   'tmin': '4,5',
#   'tmax': '18,2',
#   'sol': '8,7'},
#  {'fecha': '2017-01-26',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '9,2',
#   'prec': '1,3',
#   'tmin': '4,0',
#   'tmax': '14,4',
#   'sol': '5,1'},
#  {'fecha': '2017-01-27',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,8',
#   'prec': '6,6',
#   'tmin': '8,5',
#   'tmax': '15,0',
#   'sol': '5,8'},
#  {'fecha': '2017-01-28',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,2',
#   'prec': '0,1',
#   'tmin': '7,0',
#   'tmax': '17,5'},
#  {'fecha': '2017-01-29',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,8',
#   'prec': '0,0',
#   'tmin': '6,2',
#   'tmax': '17,5',
#   'sol': '4,8'},
#  {'fecha': '2017-01-30',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,2',
#   'prec': '0,0',
#   'tmin': '12,0',
#   'tmax': '18,5',
#   'sol': '3,0'},
#  {'fecha': '2017-01-31',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,2',
#   'prec': '0,0',
#   'tmin': '6,8',
#   'tmax': '15,7',
#   'sol': '7,3'},
#  {'fecha': '2017-02-01',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,2',
#   'prec': '0,0',
#   'tmin': '8,0',
#   'tmax': '20,5',
#   'sol': '5,8'},
#  {'fecha': '2017-02-02',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,9',
#   'prec': '1,8',
#   'tmin': '11,0',
#   'tmax': '16,8',
#   'sol': '0,0'},
#  {'fecha': '2017-02-03',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,4',
#   'prec': '0,0',
#   'tmin': '12,2',
#   'tmax': '20,6',
#   'sol': '4,7'},
#  {'fecha': '2017-02-04',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '18,1',
#   'prec': '0,0',
#   'tmin': '15,4',
#   'tmax': '20,8',
#   'sol': '0,0'},
#  {'fecha': '2017-02-05',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,3',
#   'prec': '1,2',
#   'tmin': '14,9',
#   'tmax': '17,7',
#   'sol': '7,6'},
#  {'fecha': '2017-02-06',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,0',
#   'prec': '0,0',
#   'tmin': '9,5',
#   'tmax': '20,6',
#   'sol': '3,2'},
#  {'fecha': '2017-02-07',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '17,4',
#   'prec': '0,0',
#   'tmin': '12,8',
#   'tmax': '22,0',
#   'sol': '6,0'},
#  {'fecha': '2017-02-08',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,8',
#   'prec': '0,0',
#   'tmin': '9,3',
#   'tmax': '20,2',
#   'sol': '0,0'},
#  {'fecha': '2017-02-09',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,0',
#   'prec': '0,0',
#   'tmin': '8,4',
#   'tmax': '19,5',
#   'sol': '8,5'},
#  {'fecha': '2017-02-10',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '10,8',
#   'prec': '0,1',
#   'tmin': '4,9',
#   'tmax': '16,6',
#   'sol': '5,2'},
#  {'fecha': '2017-02-11',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '11,2',
#   'prec': 'Ip',
#   'tmin': '9,3',
#   'tmax': '13,1',
#   'sol': '0,0'},
#  {'fecha': '2017-02-12',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,6',
#   'prec': '0,0',
#   'tmin': '12,1',
#   'tmax': '19,0',
#   'sol': '1,2'},
#  {'fecha': '2017-02-13',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '16,8',
#   'prec': '3,2',
#   'tmin': '13,0',
#   'tmax': '20,5',
#   'sol': '8,3'},
#  {'fecha': '2017-02-14',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,9',
#   'prec': '0,0',
#   'tmin': '8,0',
#   'tmax': '19,8',
#   'sol': '7,9'},
#  {'fecha': '2017-02-15',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,2',
#   'prec': '0,0',
#   'tmin': '6,5',
#   'tmax': '18,0',
#   'sol': '4,8'},
#  {'fecha': '2017-02-16',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,6',
#   'prec': '0,0',
#   'tmin': '8,3',
#   'tmax': '17,0',
#   'sol': '5,1'},
#  {'fecha': '2017-02-17',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,6',
#   'prec': '0,0',
#   'tmin': '7,2',
#   'tmax': '18,0',
#   'sol': '7,6'},
#  {'fecha': '2017-02-18',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,0',
#   'prec': '0,0',
#   'tmin': '6,9',
#   'tmax': '17,1',
#   'sol': '8,9'},
#  {'fecha': '2017-02-19',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,4',
#   'prec': '0,0',
#   'tmin': '10,8',
#   'tmax': '16,0',
#   'sol': '3,3'},
#  {'fecha': '2017-02-20',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,0',
#   'prec': '0,0',
#   'tmin': '6,5',
#   'tmax': '17,6',
#   'sol': '9,8'},
#  {'fecha': '2017-02-21',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,4',
#   'prec': '0,0',
#   'tmin': '5,8',
#   'tmax': '19,0',
#   'sol': '9,2'},
#  {'fecha': '2017-02-22',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,0',
#   'prec': 'Ip',
#   'tmin': '7,6',
#   'tmax': '18,3',
#   'sol': '4,8'},
#  {'fecha': '2017-02-23',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,3',
#   'prec': '3,4',
#   'tmin': '10,5',
#   'tmax': '18,1',
#   'sol': '1,7'},
#  {'fecha': '2017-02-24',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,3',
#   'prec': '2,8',
#   'tmin': '11,2',
#   'tmax': '15,4',
#   'sol': '0,3'},
#  {'fecha': '2017-02-25',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '12,1',
#   'prec': '0,0',
#   'tmin': '7,0',
#   'tmax': '17,2',
#   'sol': '9,5'},
#  {'fecha': '2017-02-26',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,1',
#   'prec': '0,0',
#   'tmin': '8,4',
#   'tmax': '19,8',
#   'sol': '9,3'},
#  {'fecha': '2017-02-27',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,2',
#   'prec': '0,0',
#   'tmin': '8,6',
#   'tmax': '21,8',
#   'sol': '9,6'},
#  {'fecha': '2017-02-28',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,4',
#   'prec': '0,0',
#   'tmin': '12,6',
#   'tmax': '18,1',
#   'sol': '0,7'},
#  {'fecha': '2017-03-01',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '15,8',
#   'prec': '0,0',
#   'tmin': '10,3',
#   'tmax': '21,4',
#   'sol': '4,8'}]

# %%
fechaIniStr='2016-01-01T00%3A00%3A00UTC'
fechaFinStr= '2016-15-01T00:00:00UTC'
idema= '8416'

def aenet_call(fechaIniStr, fechaFinStr, idema):
    '''calls AENET API'''
    api_key= "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJkZWxhZnVlbnRlLmVsZW5hQGdtYWlsLmNvbSIsImp0aSI6IjU2ZjY1YWExLTBhMDMtNDU0Ny04MTY4LWFmZjdlN2NmNGFkYiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNTc2MDA5MjE2LCJ1c2VySWQiOiI1NmY2NWFhMS0wYTAzLTQ1NDctODE2OC1hZmY3ZTdjZjRhZGIiLCJyb2xlIjoiIn0.mXzVnU06yA2hXAR4fJkyOmTXC7RfAYxTVPESkNBhvaM"
    headers = {'cache-control': "no-cache"}
    url = f'https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fechaIniStr}/fechafin/{fechaFinStr}/estacion/{idema}'
    response = requests.request('GET', url, headers=headers, params= {"api_key":api_key} )
    return json.loads(response.text)
