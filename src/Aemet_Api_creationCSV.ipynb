# %%
import requests
import json
import pandas as pd

# %%
# Instrucciones 

# fecha Valencia a partir del 2016 Noviembre
# Fecha LP a partir de 2017 Marzo

#Fecha Inicial (AAAA-MM-DDTHH:MM:SSUTC)

# %%
fechaIniStr='2016-01-01T00%3A00%3A00UTC'
fechaFinStr= '2016-01-15T00:00:00UTC'
idema= '8416'

def aenet_call(fechaIniStr, fechaFinStr, idema):
    '''calls AENET API'''
    api_key= "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJkZWxhZnVlbnRlLmVsZW5hQGdtYWlsLmNvbSIsImp0aSI6IjU2ZjY1YWExLTBhMDMtNDU0Ny04MTY4LWFmZjdlN2NmNGFkYiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNTc2MDA5MjE2LCJ1c2VySWQiOiI1NmY2NWFhMS0wYTAzLTQ1NDctODE2OC1hZmY3ZTdjZjRhZGIiLCJyb2xlIjoiIn0.mXzVnU06yA2hXAR4fJkyOmTXC7RfAYxTVPESkNBhvaM"
    headers = {'cache-control': "no-cache"}
    url = f'https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fechaIniStr}/fechafin/{fechaFinStr}/estacion/{idema}'
    response = requests.request('GET', url, headers=headers, params= {"api_key":api_key} )
    return json.loads(response.text)

# %%
#respuesta=aenet_call('2016-01-01T00%3A00%3A00UTC', '2016-15-01T00:00:00UTC','8416')
#respuesta

# %%
#print(type(respuesta))
#respuesta['datos']

# %%
#def getdatos(url):
    #'''downloads data from URL'''
   # response = requests.get(url)
    #return json.loads(response.text)

# %%
#info=getdatos(respuesta['datos'])
#info

# %%
# fecha Valencia a partir del 2016 Noviembre
# Fecha LP a partir de 2017 Marzo

# %%
def aenet_call(fechaIniStr, fechaFinStr, idema):
    '''calls AENET API'''
    api_key= "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJkZWxhZnVlbnRlLmVsZW5hQGdtYWlsLmNvbSIsImp0aSI6IjU2ZjY1YWExLTBhMDMtNDU0Ny04MTY4LWFmZjdlN2NmNGFkYiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNTc2MDA5MjE2LCJ1c2VySWQiOiI1NmY2NWFhMS0wYTAzLTQ1NDctODE2OC1hZmY3ZTdjZjRhZGIiLCJyb2xlIjoiIn0.mXzVnU06yA2hXAR4fJkyOmTXC7RfAYxTVPESkNBhvaM"
    headers = {'cache-control': "no-cache"}
    url = f'https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fechaIniStr}/fechafin/{fechaFinStr}/estacion/{idema}'
    response = requests.request('GET', url, headers=headers, params= {"api_key":api_key} )
    jsonresponse = json.loads(response.text)['datos']
    getresponse = requests.get(jsonresponse)
    return json.loads(getresponse.text)


#Fecha Inicial (AAAA-MM-DDTHH:MM:SSUTC)
respuesta=aenet_call('2016-11-30T00%3A00%3A00UTC','2019-12-10T00:00:00UTC','8416')
respuesta
# Out:
# [{'fecha': '2016-11-30',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,6',
#   'prec': '0,3',
#   'tmin': '11,4',
#   'tmax': '15,9',
#   'sol': '0,5'},
#  {'fecha': '2016-12-01',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '14,4',
#   'prec': '0,0',
#   'tmin': '12,4',
#   'tmax': '16,3',
#   'sol': '0,7'},
#  {'fecha': '2016-12-02',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,4',
#   'prec': '0,0',
#   'tmin': '9,2',
#   'tmax': '17,7',
#   'sol': '7,9'},
#  {'fecha': '2016-12-03',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'tmed': '13,2',
#   'prec': '6,6',
#   'tmin': '8,4',
#   'tmax': '18,0',
#   'sol': '0,8'},
#  {'fecha': '2016-12-04',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
# ...

# %%
VAL= pd.DataFrame(respuesta)

# %%
VAL.columns
# Out:
# Index(['fecha', 'indicativo', 'nombre', 'provincia', 'altitud', 'tmed', 'prec',
#        'tmin', 'tmax', 'sol'],
#       dtype='object')

# %%
VAL.shape
# Out:
# (1104, 10)

# %%
VAL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 10 columns):
# fecha         1104 non-null object
# indicativo    1104 non-null object
# nombre        1104 non-null object
# provincia     1104 non-null object
# altitud       1104 non-null object
# tmed          1104 non-null object
# prec          1103 non-null object
# tmin          1104 non-null object
# tmax          1104 non-null object
# sol           1088 non-null object
# dtypes: object(10)
# memory usage: 86.4+ KB

# %%
# last information
VAL.iloc[[1103]]
# Out:
#            fecha indicativo    nombre provincia altitud  tmed prec tmin  tmax  \
# 1103  2019-12-08       8416  VALÈNCIA  VALENCIA      11  13,1  NaN  8,1  18,1
#
#       sol
# 1103  NaN

# %%
sum_null= VAL['prec'].isna().sum()

print(f'how many fields are NaN? {sum_null}')
# Out:
# how many fields are NaN? 1

# %%
VAL.isna().sum()
# Out:
# fecha          0
# indicativo     0
# nombre         0
# provincia      0
# altitud        0
# tmed           0
# prec           1
# tmin           0
# tmax           0
# sol           16
# dtype: int64

# %%
VAL
# Out:
#            fecha indicativo    nombre provincia altitud  tmed  prec  tmin  \
# 0     2016-11-30       8416  VALÈNCIA  VALENCIA      11  13,6   0,3  11,4
# 1     2016-12-01       8416  VALÈNCIA  VALENCIA      11  14,4   0,0  12,4
# 2     2016-12-02       8416  VALÈNCIA  VALENCIA      11  13,4   0,0   9,2
# 3     2016-12-03       8416  VALÈNCIA  VALENCIA      11  13,2   6,6   8,4
# 4     2016-12-04       8416  VALÈNCIA  VALENCIA      11  15,2   8,6  13,5
# ...          ...        ...       ...       ...     ...   ...   ...   ...
# 1099  2019-12-04       8416  VALÈNCIA  VALENCIA      11  12,6  29,3  10,5
# 1100  2019-12-05       8416  VALÈNCIA  VALENCIA      11  12,8  15,2  11,0
# 1101  2019-12-06       8416  VALÈNCIA  VALENCIA      11  13,4   0,0  11,7
# 1102  2019-12-07       8416  VALÈNCIA  VALENCIA      11  13,4   0,0   8,5
# 1103  2019-12-08       8416  VALÈNCIA  VALENCIA      11  13,1   NaN   8,1
#
#       tmax  sol
# 0     15,9  0,5
# 1     16,3  0,7
# 2     17,7  7,9
# ...

# %%
#Fecha Inicial (AAAA-MM-DDTHH:MM:SSUTC)
respuesta=aenet_call('2016-11-30T00%3A00%3A00UTC','2019-12-10T00:00:00UTC','C659H')
respuesta
# Out:
# [{'fecha': '2016-11-30',
#   'indicativo': 'C659H',
#   'nombre': 'LAS PALMAS DE GRAN CANARIA, SAN CRISTOBAL',
#   'provincia': 'LAS PALMAS',
#   'altitud': '55',
#   'tmed': '21,9',
#   'prec': '0,0',
#   'tmin': '17,8',
#   'horatmin': '04:50',
#   'tmax': '26,0',
#   'horatmax': '11:40',
#   'dir': '26',
#   'velmedia': '1,7',
#   'racha': '8,6',
#   'horaracha': '21:50'},
#  {'fecha': '2016-12-01',
#   'indicativo': 'C659H',
#   'nombre': 'LAS PALMAS DE GRAN CANARIA, SAN CRISTOBAL',
#   'provincia': 'LAS PALMAS',
#   'altitud': '55',
#   'tmed': '21,8',
#   'prec': '0,0',
#   'tmin': '17,9',
#   'horatmin': '04:40',
#   'tmax': '25,6',
#   'horatmax': '14:40',
#   'dir': '15',
#   'velmedia': '1,7',
#   'racha': '5,0',
#   'horaracha': '17:00'},
#  {'fecha': '2016-12-02',
#   'indicativo': 'C659H',
#   'nombre': 'LAS PALMAS DE GRAN CANARIA, SAN CRISTOBAL',
#   'provincia': 'LAS PALMAS',
#   'altitud': '55',
#   'tmed': '22,4',
#   'prec': '0,0',
#   'tmin': '18,8',
# ...

# %%
LP= pd.DataFrame(respuesta)

# %%
LP.shape
LP.columns
# Out:
# Index(['fecha', 'indicativo', 'nombre', 'provincia', 'altitud', 'tmed', 'prec',
#        'tmin', 'horatmin', 'tmax', 'horatmax', 'dir', 'velmedia', 'racha',
#        'horaracha'],
#       dtype='object')

# %%
VAL.shape
VAL.columns
# Out:
# Index(['fecha', 'indicativo', 'nombre', 'provincia', 'altitud', 'tmed', 'prec',
#        'tmin', 'tmax', 'sol'],
#       dtype='object')

# %%
LP['puerto']='01'
LP.columns
# Out:
# Index(['fecha', 'indicativo', 'nombre', 'provincia', 'altitud', 'tmed', 'prec',
#        'tmin', 'horatmin', 'tmax', 'horatmax', 'dir', 'velmedia', 'racha',
#        'horaracha', 'puerto'],
#       dtype='object')

# %%
VAL['puerto']='02'
VAL.columns
# Out:
# Index(['fecha', 'indicativo', 'nombre', 'provincia', 'altitud', 'tmed', 'prec',
#        'tmin', 'tmax', 'sol', 'puerto'],
#       dtype='object')

# %%
VALoriginal=VAL.to_csv('../output/VALoriginal.csv')

# %%
LPoriginal=LP.to_csv('../output/LPoriginal.csv')
